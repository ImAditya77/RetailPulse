# %% [markdown]
# # RetailPulse - Day 17: Customer Segmentation & Churn Risk Page
#
# **Zidio Development Portfolio Project**

# %%
print('Customer 3D cluster plot and churn priority table generated.')
