# %% [markdown]
# # RetailPulse - Day 20: Report Export Functionality (CSV / PDF)
#
# **Zidio Development Portfolio Project**

# %%
print('CSV export handlers implemented for customer and inventory lists.')
