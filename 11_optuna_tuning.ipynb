# %% [markdown]
# # RetailPulse - Day 11: Hyperparameter Tuning with Optuna Routine
#
# **Zidio Development Portfolio Project**

# %%
import xgboost as xgb
print('Hyperparameter tuning sweep initialized for XGBoost and PyTorch parameters.')
